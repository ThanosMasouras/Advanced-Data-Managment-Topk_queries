# %%
R = {}
with open("rnd.txt", "r") as rnd_file:
    for line in rnd_file:
        obj_id, score = line.split()
        R[int(obj_id)] = float(score)

# %%
seq1_file = open("seq1.txt", "r")
seq2_file = open("seq2.txt", "r")
seq1_line = seq1_file.readline()
seq2_line = seq2_file.readline()
k = 5
objs_checked = 0
T = 0
Wk = {}
wk_created = 0
lower_bounds = {}
total_scores = {}
objs_seq1 = []
objs_seq2 = []
sequential_accesses = 2
terminate = False

# %%
while seq1_line and seq2_line:
    seq1_obj_id, seq1_score = seq1_line.split()
    seq1_obj_id = int(seq1_obj_id)
    seq1_score = float(seq1_score)
    
    seq2_obj_id, seq2_score = seq2_line.split()
    seq2_obj_id = int(seq2_obj_id)
    seq2_score = float(seq2_score)
    
    if seq1_obj_id in lower_bounds:
        total_scores[seq1_obj_id] = round(lower_bounds[seq1_obj_id] + seq1_score,2)
    else:
        objs_checked += 1
        lower_bounds[seq1_obj_id] = round(R[seq1_obj_id] + seq1_score,2)
        objs_seq1.append(seq1_obj_id)
        
    if objs_checked == k:
        sorted_lower_bounds = sorted(lower_bounds.items(), key=lambda x: x[1] or 0, reverse=True)
        top_k_objs = sorted_lower_bounds[:k]
        Wk = [(key, value) for key, value in top_k_objs]
        wk_created = 1
        
    if Wk and seq1_obj_id in total_scores:    
        if total_scores[seq1_obj_id] > Wk[4][1]:
            Wk[4] = (seq1_obj_id,total_scores[seq1_obj_id])
            Wk = sorted(Wk, key=lambda x:x[1], reverse = True)
    
    
    if seq2_obj_id in lower_bounds:
        total_scores[seq2_obj_id] = round(lower_bounds[seq2_obj_id] + seq2_score,2)
    else:
        objs_checked += 1
        lower_bounds[seq2_obj_id] = round(R[seq2_obj_id] + seq2_score,2)
        objs_seq2.append(seq2_obj_id)
        
    if objs_checked == k:
        sorted_lower_bounds = sorted(lower_bounds.items(), key=lambda x: x[1] or 0, reverse=True)
        Wk = [(key, value) for key, value in top_k_objs]
        wk_created = 1
    
    if Wk and seq2_obj_id in total_scores:
        if total_scores[seq2_obj_id] > Wk[4][1]:
            Wk[4] = (seq2_obj_id,total_scores[seq2_obj_id])
            Wk = sorted(Wk, key=lambda x:x[1], reverse = True)

    if wk_created == 1: 
        if Wk[4][1] >= T:
            terminate = True
            for key in lower_bounds:
                if key not in objs_seq1:
                    if Wk[4][1] < round(lower_bounds[key] + seq1_score,2) and key not in total_scores:
                        terminate = False
                else:
                    if Wk[4][1] < round(lower_bounds[key] + seq2_score,2) and key not in total_scores:
                        terminate = False
            if terminate == True:
                print(sequential_accesses)
                print(Wk)
                break 
            
            
    
    T = round(seq1_score + seq2_score + 5.00,2)
    sequential_accesses +=2
    if sequential_accesses >= 3500:
        print(T)
        print(Wk[4][1])
        break
    seq1_line = seq1_file.readline()
    seq2_line = seq2_file.readline()
# Out:
# 3018
# [(50905, 14.84), (85861, 14.76), (22652, 14.74), (75232, 14.74), (20132, 14.74)]

# %%
seq1_obj_id
# Out:
# 66529

# %%
lower_bounds[33136]
# Out:
# 9.4

# %%
lower_bounds
# Out:
# {33136: 9.4,
#  54393: 9.76,
#  11283: 9.69,
#  53305: 9.48,
#  16675: 9.82,
#  20865: 9.44,
#  51990: 9.64,
#  86655: 8.71,
#  78457: 9.49,
#  1585: 9.21,
#  85743: 9.37,
#  76361: 9.11,
#  6299: 9.35,
#  6331: 8.82,
#  22873: 9.92,
#  41625: 9.36,
#  9816: 9.35,
#  32445: 8.75,
#  82846: 9.76,
#  94634: 8.91,
#  20287: 9.93,
#  55337: 9.35,
#  55165: 9.66,
#  65677: 8.57,
#  95862: 9.27,
#  97272: 8.73,
#  15335: 9.4,
#  37158: 8.47,
#  67859: 9.26,
#  25394: 8.39,
#  15804: 9.77,
#  99758: 8.72,
#  91290: 9.42,
#  71603: 6.97,
#  70756: 9.27,
#  83800: 9.28,
#  11541: 9.71,
#  92741: 9.0,
#  67855: 9.12,
#  55986: 9.27,
#  85001: 9.63,
#  72789: 8.38,
#  78994: 9.0,
#  83930: 8.22,
#  40310: 9.14,
#  99696: 8.64,
#  90610: 9.28,
#  67755: 8.78,
#  27500: 9.71,
#  93669: 8.35,
#  65440: 9.67,
#  35008: 8.34,
#  41892: 9.71,
#  60906: 8.88,
#  47271: 9.17,
#  59994: 8.85,
#  17949: 9.53,
#  60420: 9.19,
#  42781: 9.13,
#  56279: 8.83,
#  17603: 8.74,
#  55519: 8.17,
#  65219: 9.49,
#  80354: 8.96,
#  91352: 9.2,
#  91052: 8.84,
#  65442: 9.38,
#  59824: 9.14,
#  70195: 9.33,
#  80747: 8.69,
#  26709: 9.32,
#  9465: 8.64,
#  92208: 9.89,
#  86874: 8.77,
#  9745: 9.83,
#  11152: 8.51,
#  35055: 9.84,
#  43401: 8.99,
#  57678: 8.84,
#  58422: 8.73,
#  64350: 9.64,
#  86123: 9.3,
#  91037: 9.78,
#  14534: 8.67,
#  87231: 9.33,
#  69375: 8.98,
#  73841: 8.88,
#  16023: 9.02,
#  45962: 9.59,
#  48615: 8.95,
#  69156: 8.91,
#  49667: 9.52,
#  26118: 9.1,
#  69427: 8.77,
#  12788: 8.95,
#  54829: 9.59,
#  35411: 9.13,
#  47435: 8.17,
#  28197: 9.49,
#  86547: 8.35,
#  80191: 9.29,
#  45681: 9.43,
#  95480: 8.87,
#  93248: 9.33,
#  80398: 9.07,
#  30398: 9.26,
#  23450: 9.06,
#  74243: 9.09,
#  60687: 9.36,
#  4277: 8.5,
#  86960: 8.82,
#  50905: 9.96,
#  15499: 9.6,
#  13826: 9.41,
#  41038: 9.28,
#  98515: 9.52,
#  6273: 9.42,
#  63390: 8.93,
#  69959: 9.69,
#  45379: 8.85,
#  48658: 9.33,
#  550: 9.45,
#  40323: 9.12,
#  91148: 8.62,
#  37524: 9.75,
#  93635: 8.66,
#  19497: 9.4,
#  81864: 9.07,
#  9052: 9.34,
#  62884: 9.35,
#  83777: 9.61,
#  49901: 9.36,
#  80032: 9.24,
#  67704: 8.75,
#  5598: 9.63,
#  31841: 8.2,
#  72998: 8.92,
#  65398: 8.87,
#  82069: 9.27,
#  32566: 8.46,
#  98495: 9.57,
#  2536: 9.64,
#  89290: 9.32,
#  84435: 8.58,
#  95403: 9.62,
#  99635: 7.83,
#  64712: 9.27,
#  78491: 8.56,
#  55227: 8.92,
#  16580: 8.97,
#  97866: 9.95,
#  86041: 9.54,
#  95024: 9.86,
#  76449: 9.03,
#  66018: 8.96,
#  25312: 7.95,
#  74466: 9.74,
#  66686: 8.11,
#  34296: 9.3,
#  87868: 7.95,
#  54277: 9.5,
#  86137: 8.99,
#  37663: 9.24,
#  94437: 8.69,
#  58825: 9.3,
#  3292: 9.53,
#  63773: 9.83,
#  22652: 9.8,
#  58591: 9.06,
#  50699: 8.81,
#  4084: 9.12,
#  88454: 9.06,
#  9041: 9.85,
#  30019: 8.6,
#  95540: 9.76,
#  76334: 7.88,
#  51441: 9.76,
#  87084: 9.7,
#  96594: 9.27,
#  33773: 8.79,
#  50095: 9.09,
#  751: 9.19,
#  952: 9.73,
#  95613: 9.09,
#  46782: 9.5,
#  19894: 9.14,
#  21824: 9.72,
#  10090: 8.19,
#  44642: 9.04,
#  55803: 8.57,
#  59433: 9.33,
#  30912: 8.06,
#  98299: 9.26,
#  79447: 8.8,
#  66159: 9.45,
#  85861: 9.88,
#  7578: 8.71,
#  85355: 8.92,
#  16538: 7.75,
#  88558: 9.05,
#  75232: 9.91,
#  79330: 9.53,
#  10893: 9.19,
#  27852: 9.16,
#  15501: 7.84,
#  54842: 9.37,
#  21902: 9.05,
#  75711: 9.45,
#  85292: 8.65,
#  13877: 9.07,
#  60430: 9.36,
#  42704: 9.08,
#  10032: 7.93,
#  32833: 9.48,
#  43682: 9.56,
#  78580: 9.5,
#  36199: 9.6,
#  19205: 9.0,
#  19780: 8.24,
#  99336: 9.43,
#  87181: 8.49,
#  48255: 9.36,
#  39818: 8.91,
#  78485: 8.77,
#  35130: 9.45,
#  7906: 9.54,
#  30464: 8.56,
#  14416: 9.68,
#  58820: 8.66,
#  56750: 9.8,
#  43527: 9.18,
#  32448: 9.09,
#  88356: 9.28,
#  65329: 9.64,
#  37025: 9.15,
#  87781: 9.0,
#  37441: 8.35,
#  85832: 8.44,
#  15199: 9.73,
#  91691: 9.48,
#  48082: 9.28,
#  77937: 9.39,
#  15095: 8.41,
#  4885: 9.66,
#  85833: 8.81,
#  44966: 9.13,
#  83092: 8.38,
#  77708: 9.49,
#  61449: 8.57,
#  49137: 9.89,
#  55436: 8.18,
#  84350: 9.35,
#  11895: 8.5,
#  68384: 8.63,
#  3280: 8.93,
#  40861: 9.19,
#  29144: 8.73,
#  51954: 9.33,
#  95205: 8.74,
#  78279: 8.94,
#  53246: 8.86,
#  81729: 9.41,
#  16614: 9.59,
#  81433: 9.39,
#  83992: 8.33,
#  99714: 9.36,
#  68727: 8.68,
#  74850: 9.06,
#  17015: 9.34,
#  73434: 9.47,
#  21888: 8.95,
#  84644: 9.41,
#  3481: 7.95,
#  10396: 9.66,
#  57781: 8.38,
#  4839: 9.15,
#  53239: 7.92,
#  14763: 9.37,
#  40052: 8.94,
#  62886: 8.97,
#  15454: 8.74,
#  15807: 8.73,
#  90082: 9.28,
#  500: 9.34,
#  79696: 8.65,
#  98736: 8.91,
#  94171: 9.63,
#  10413: 9.24,
#  49055: 9.08,
#  65768: 9.05,
#  28418: 8.69,
#  86156: 8.87,
#  27620: 8.43,
#  1680: 9.33,
#  53437: 9.4,
#  62181: 8.51,
#  61455: 8.77,
#  82733: 8.71,
#  2072: 8.87,
#  33288: 9.6,
#  77870: 9.28,
#  2893: 9.05,
#  33408: 8.25,
#  27163: 9.13,
#  44274: 9.33,
#  34821: 9.05,
#  27788: 9.78,
#  16799: 9.15,
#  91638: 8.87,
#  36187: 8.3,
#  8737: 9.23,
#  63363: 8.75,
#  64616: 8.83,
#  53910: 8.19,
#  89755: 9.25,
#  51979: 9.49,
#  19118: 9.38,
#  79760: 8.93,
#  9014: 9.05,
#  74617: 7.95,
#  26694: 9.35,
#  63172: 8.46,
#  17377: 9.01,
#  75479: 8.54,
#  1789: 9.19,
#  80914: 8.09,
#  74528: 9.67,
#  20981: 8.91,
#  11595: 9.52,
#  64209: 8.49,
#  96774: 9.06,
#  81313: 9.06,
#  79184: 9.52,
#  35422: 8.47,
#  95175: 9.05,
#  99733: 9.08,
#  47364: 8.96,
#  80102: 8.93,
#  23037: 9.17,
#  80524: 7.52,
#  60992: 9.03,
#  75728: 8.67,
#  11825: 8.93,
#  41183: 8.58,
#  23068: 8.76,
#  32318: 8.89,
#  19991: 9.1,
#  92389: 8.79,
#  33935: 8.94,
#  16162: 9.65,
#  88156: 8.57,
#  99068: 9.35,
#  50307: 9.51,
#  19689: 8.97,
#  39355: 8.3,
#  69876: 9.8,
#  23812: 7.8,
#  1056: 9.33,
#  87190: 8.87,
#  62673: 9.48,
#  96738: 8.27,
#  26906: 9.16,
#  25709: 9.29,
#  30062: 9.73,
#  43960: 9.15,
#  87099: 9.08,
#  28277: 7.97,
#  28021: 9.54,
#  66822: 8.7,
#  56588: 8.84,
#  78134: 8.87,
#  49215: 8.71,
#  92938: 8.5,
#  28688: 9.01,
#  91868: 8.85,
#  47203: 8.3,
#  15756: 8.03,
#  61351: 8.92,
#  87356: 9.13,
#  84871: 8.87,
#  99297: 8.8,
#  83852: 9.45,
#  4903: 7.91,
#  2313: 9.04,
#  76257: 8.98,
#  22043: 8.63,
#  87859: 8.73,
#  18250: 8.96,
#  64206: 9.65,
#  43632: 9.23,
#  59071: 8.41,
#  63358: 8.73,
#  60746: 8.07,
#  86834: 8.68,
#  43464: 8.73,
#  99057: 9.04,
#  11508: 8.77,
#  43842: 9.33,
#  97778: 8.71,
#  67494: 8.22,
#  6695: 9.21,
#  4067: 8.43,
#  18314: 9.72,
#  41723: 8.79,
#  95494: 9.11,
#  2906: 8.7,
#  379: 9.38,
#  64419: 9.26,
#  66491: 9.66,
#  71952: 9.21,
#  55894: 9.44,
#  90559: 7.67,
#  20132: 9.85,
#  50548: 9.53,
#  62552: 9.16,
#  33328: 9.3,
#  1639: 8.23,
#  94966: 9.07,
#  19479: 8.7,
#  43968: 9.27,
#  14594: 8.85,
#  35361: 8.53,
#  84686: 8.37,
#  50385: 9.41,
#  37725: 8.52,
#  96856: 9.55,
#  36676: 8.65,
#  76229: 8.93,
#  18755: 8.4,
#  56109: 9.47,
#  60122: 8.53,
#  60602: 8.99,
#  19178: 8.48,
#  59781: 8.88,
#  853: 8.82,
#  22788: 9.22,
#  84292: 9.5,
#  86517: 9.78,
#  21832: 8.44,
#  48376: 9.06,
#  2454: 8.84,
#  81472: 9.43,
#  24883: 9.16,
#  19532: 9.81,
#  27214: 8.29,
#  40992: 9.03,
#  50001: 8.93,
#  55484: 9.32,
#  15343: 9.04,
#  651: 9.46,
#  88880: 8.76,
#  47208: 9.5,
#  18699: 9.13,
#  96407: 9.7,
#  90436: 8.44,
#  3820: 9.08,
#  9950: 7.91,
#  73476: 9.34,
#  8864: 8.63,
#  85629: 9.52,
#  36682: 8.22,
#  75192: 9.29,
#  36330: 8.85,
#  45732: 9.01,
#  63359: 9.41,
#  83899: 8.49,
#  18758: 8.81,
#  12052: 8.91,
#  78206: 8.42,
#  1473: 8.74,
#  31674: 9.51,
#  24929: 9.0,
#  12786: 9.5,
#  1677: 8.34,
#  66312: 9.22,
#  52499: 8.7,
#  52722: 9.16,
#  43388: 8.51,
#  16561: 9.37,
#  21845: 7.97,
#  39010: 9.16,
#  60308: 8.52,
#  6237: 9.19,
#  61767: 8.74,
#  94860: 9.72,
#  91657: 8.64,
#  7923: 8.94,
#  77193: 8.9,
#  80450: 9.57,
#  45750: 8.77,
#  60797: 9.61,
#  32291: 8.72,
#  5527: 9.45,
#  26760: 8.62,
#  80364: 8.83,
#  77717: 8.72,
#  50256: 8.91,
#  42600: 9.22,
#  92977: 9.61,
#  46821: 9.5,
#  79457: 9.32,
#  70537: 8.94,
#  83759: 9.73,
#  5804: 7.92,
#  5582: 9.33,
#  96230: 7.87,
#  77328: 8.74,
#  52771: 8.72,
#  74731: 9.78,
#  5631: 8.25,
#  43220: 9.53,
#  25405: 9.69,
#  76149: 9.09,
#  56013: 7.88,
#  55580: 8.66,
#  48623: 8.98,
#  37313: 9.51,
#  97326: 8.78,
#  59506: 9.3,
#  20405: 8.67,
#  27541: 8.96,
#  81956: 8.17,
#  3873: 9.13,
#  99691: 7.84,
#  64705: 9.56,
#  48914: 7.74,
#  74235: 9.31,
#  18864: 8.73,
#  12: 8.92,
#  69255: 7.72,
#  23963: 9.29,
#  39016: 8.87,
#  32274: 9.24,
#  90868: 8.38,
#  94388: 9.31,
#  5489: 9.2,
#  16966: 9.37,
#  83865: 9.22,
#  19803: 8.26,
#  27978: 8.51,
#  61639: 9.44,
#  51246: 8.46,
#  84722: 9.71,
#  58345: 9.29,
#  64650: 9.07,
#  37918: 9.12,
#  26690: 8.87,
#  42866: 8.86,
#  77904: 9.0,
#  6801: 8.63,
#  28323: 9.25,
#  39382: 8.46,
#  16564: 9.65,
#  43938: 8.59,
#  31685: 9.43,
#  39895: 8.94,
#  16164: 8.8,
#  20836: 9.14,
#  82030: 8.85,
#  90624: 9.54,
#  66881: 8.77,
#  22543: 9.59,
#  47539: 9.08,
#  30157: 8.64,
#  4584: 9.18,
#  58016: 8.11,
#  19488: 9.3,
#  36399: 8.69,
#  41202: 9.12,
#  74820: 8.69,
#  65090: 8.7,
#  53385: 8.63,
#  78930: 8.98,
#  27705: 8.63,
#  82504: 8.91,
#  72578: 8.02,
#  53922: 9.28,
#  56627: 9.25,
#  65535: 9.23,
#  77765: 8.6,
#  35819: 9.17,
#  64891: 8.79,
#  54582: 9.17,
#  39554: 9.08,
#  92801: 9.59,
#  45795: 9.06,
#  78738: 9.12,
#  594: 9.74,
#  50774: 9.05,
#  63272: 8.83,
#  22482: 9.66,
#  18048: 9.6,
#  82374: 9.13,
#  82432: 9.03,
#  23220: 9.43,
#  92429: 8.58,
#  52144: 9.4,
#  57763: 8.42,
#  44888: 8.64,
#  60017: 7.96,
#  22319: 8.76,
#  73713: 8.52,
#  57531: 9.22,
#  41478: 9.27,
#  1845: 8.87,
#  64310: 8.28,
#  22470: 9.06,
#  2807: 8.42,
#  30866: 9.17,
#  88743: 8.84,
#  58615: 8.57,
#  83370: 8.86,
#  86876: 9.34,
#  85725: 8.54,
#  205: 8.88,
#  50053: 8.5,
#  86839: 9.17,
#  58231: 8.12,
#  60947: 9.06,
#  26963: 8.83,
#  68981: 8.75,
#  62334: 9.31,
#  14240: 8.5,
#  8685: 9.03,
#  66850: 8.99,
#  79426: 9.62,
#  86441: 8.3,
#  26024: 8.87,
#  77630: 8.84,
#  66834: 9.38,
#  41360: 8.04,
#  1693: 9.36,
#  90476: 8.62,
#  29269: 9.53,
#  20269: 9.31,
#  38283: 8.73,
#  56708: 8.96,
#  37707: 9.04,
#  57224: 9.57,
#  71212: 8.26,
#  26305: 9.02,
#  6601: 9.31,
#  2180: 9.08,
#  45241: 8.21,
#  36025: 9.39,
#  1431: 8.67,
#  50935: 9.07,
#  36922: 8.34,
#  48258: 8.83,
#  95019: 9.0,
#  97880: 8.99,
#  2771: 8.12,
#  50767: 8.61,
#  73798: 8.57,
#  9292: 8.58,
#  54325: 8.73,
#  17823: 9.46,
#  55202: 8.68,
#  89792: 9.24,
#  22493: 9.37,
#  33401: 9.0,
#  28516: 8.65,
#  58513: 9.62,
#  6458: 7.91,
#  58402: 9.68,
#  99135: 8.7,
#  76874: 8.91,
#  61251: 7.95,
#  78117: 9.37,
#  34289: 8.58,
#  95855: 8.86,
#  17143: 8.76,
#  11126: 9.19,
#  57228: 9.13,
#  91882: 9.49,
#  44315: 8.81,
#  21201: 8.92,
#  53782: 8.62,
#  41435: 8.53,
#  66093: 8.43,
#  3038: 8.66,
#  63228: 8.67,
#  90912: 9.2,
#  79121: 9.39,
#  89909: 8.43,
#  53860: 8.7,
#  81230: 8.88,
#  34671: 9.5,
#  94636: 9.3,
#  20122: 8.71,
#  38377: 9.3,
#  83502: 8.33,
#  23145: 9.66,
#  99735: 8.31,
#  8700: 9.05,
#  22674: 9.45,
#  92382: 9.41,
#  99375: 8.89,
#  80358: 9.4,
#  79350: 7.99,
#  9249: 8.92,
#  81251: 8.72,
#  75960: 8.97,
#  2391: 8.68,
#  82260: 9.22,
#  84399: 8.86,
#  25059: 9.27,
#  27096: 8.1,
#  85250: 9.0,
#  81972: 9.47,
#  98300: 9.48,
#  70118: 8.55,
#  29388: 9.02,
#  32934: 9.31,
#  44023: 9.5,
#  16129: 8.64,
#  27590: 9.5,
#  51482: 8.75,
#  3627: 8.61,
#  26057: 8.72,
#  33471: 9.5,
#  46198: 9.34,
#  88832: 9.3,
#  91888: 8.8,
#  53490: 9.27,
#  35453: 9.23,
#  21406: 9.11,
#  51100: 8.51,
#  77482: 9.34,
#  91875: 8.58,
#  15208: 9.34,
#  61607: 9.33,
#  41048: 9.57,
#  58819: 9.81,
#  16658: 9.02,
#  18067: 9.47,
#  95937: 9.08,
#  2857: 8.85,
#  35467: 9.62,
#  83001: 8.55,
#  69114: 9.0,
#  22769: 8.53,
#  1355: 9.51,
#  72515: 8.47,
#  30713: 8.68,
#  99244: 8.92,
#  49947: 9.23,
#  80639: 9.06,
#  45402: 9.01,
#  76213: 9.25,
#  59229: 8.76,
#  54474: 8.19,
#  30726: 8.97,
#  93153: 9.48,
#  70642: 8.48,
#  4317: 8.25,
#  53540: 9.12,
#  69753: 8.89,
#  48211: 9.11,
#  20032: 9.02,
#  99747: 8.93,
#  13580: 8.76,
#  78315: 9.74,
#  39862: 8.0,
#  70546: 8.89,
#  28301: 8.56,
#  14732: 9.17,
#  78478: 8.29,
#  16933: 8.69,
#  34475: 8.43,
#  33014: 8.88,
#  5084: 7.96,
#  59152: 7.88,
#  46672: 8.72,
#  82953: 8.13,
#  25137: 9.0,
#  44273: 8.6,
#  4744: 9.31,
#  47597: 8.29,
#  73588: 9.03,
#  70002: 8.17,
#  77574: 9.19,
#  27992: 8.81,
#  74968: 9.25,
#  52623: 8.68,
#  44311: 9.08,
#  65516: 8.72,
#  51086: 8.89,
#  12885: 7.99,
#  66949: 9.0,
#  60959: 8.61,
#  56047: 9.15,
#  11610: 8.68,
#  85482: 9.07,
#  63168: 9.18,
#  6988: 8.38,
#  58099: 7.73,
#  33303: 9.39,
#  92865: 9.06,
#  55945: 8.94,
#  88380: 8.12,
#  90537: 9.1,
#  86490: 8.33,
#  21180: 9.18,
#  17693: 8.46,
#  36553: 8.81,
#  47504: 9.42,
#  90218: 8.94,
#  55107: 8.48,
#  99083: 9.02,
#  62289: 9.31,
#  73287: 8.59,
#  67592: 7.91,
#  22821: 8.66,
#  67992: 9.13,
#  87355: 9.17,
#  3220: 8.85,
#  89953: 8.76,
#  7321: 8.67,
#  77511: 9.41,
#  63075: 9.43,
#  70418: 8.63,
#  13689: 8.82,
#  70278: 7.66,
#  39713: 8.99,
#  26888: 8.85,
#  8220: 9.56,
#  75651: 8.82,
#  52122: 8.67,
#  66956: 9.3,
#  44895: 8.49,
#  26346: 8.73,
#  45896: 9.22,
#  81044: 8.86,
#  28159: 8.95,
#  24073: 7.64,
#  75976: 8.5,
#  11297: 8.75,
#  64423: 9.12,
#  76560: 8.74,
#  69926: 9.11,
#  81139: 8.43,
#  39304: 9.17,
#  25759: 8.99,
#  70122: 8.93,
#  76287: 8.91,
#  90860: 8.86,
#  17626: 8.7,
#  82046: 9.3,
#  26330: 8.57,
#  85440: 9.34,
#  82655: 9.17,
#  47267: 8.73,
#  56611: 8.95,
#  22317: 9.13,
#  37658: 8.04,
#  54642: 8.96,
#  52901: 8.79,
#  1915: 7.66,
#  81847: 8.59,
#  85294: 8.47,
#  87725: 9.05,
#  68058: 9.16,
#  93455: 8.7,
#  35237: 8.76,
#  2462: 8.64,
#  77712: 9.09,
#  52720: 8.89,
#  38030: 8.89,
#  10094: 8.26,
#  53961: 9.21,
#  86704: 8.9,
#  74326: 8.89,
#  84126: 8.72,
#  99346: 8.79,
#  5381: 8.96,
#  67707: 8.83,
#  42723: 8.77,
#  72714: 8.96,
#  54032: 8.67,
#  94965: 8.7,
#  68799: 8.07,
#  8848: 9.1,
#  41914: 8.46,
#  61906: 9.68,
#  15163: 9.79,
#  70675: 9.01,
#  70740: 8.75,
#  57876: 9.06,
#  65687: 8.19,
#  94855: 8.92,
#  2918: 9.31,
#  23262: 8.89,
#  78947: 9.03,
#  45653: 8.96,
#  48020: 8.5,
#  73313: 8.94,
#  23400: 8.27,
#  15605: 9.49,
#  26825: 8.48,
#  29023: 9.0,
#  41073: 8.42,
#  96625: 9.02,
#  74554: 8.47,
#  39993: 9.0,
#  73555: 9.52,
#  2926: 9.07,
#  10689: 8.5,
#  99070: 9.72,
#  76850: 8.95,
#  43827: 8.83,
#  87267: 8.93,
#  4852: 9.07,
#  25043: 9.82,
#  86500: 8.56,
#  75346: 8.39,
#  78401: 9.18,
#  85881: 9.03,
#  5679: 8.96,
#  86472: 8.57,
#  50169: 9.29,
#  5657: 8.75,
#  30985: 9.72,
#  97256: 8.2,
#  3625: 9.12,
#  10187: 8.02,
#  93976: 9.05,
#  50582: 9.54,
#  46349: 8.57,
#  3354: 8.24,
#  86296: 8.38,
#  6940: 9.18,
#  80338: 8.7,
#  9809: 8.01,
#  89903: 7.29,
#  28697: 8.73,
#  39826: 8.66,
#  3519: 8.75,
#  41290: 9.41,
#  2247: 9.53,
#  11738: 9.73,
#  80439: 9.36,
#  84568: 8.5,
#  33647: 9.03,
#  52760: 7.98,
#  36163: 8.53,
#  35536: 9.06,
#  97224: 8.39,
#  27753: 9.08,
#  43686: 8.1,
#  35087: 9.39,
#  4877: 9.62,
#  88749: 8.34,
#  10433: 9.51,
#  95572: 8.82,
#  9989: 8.04,
#  82427: 8.28,
#  19896: 8.86,
#  54052: 8.82,
#  55425: 8.23,
#  50635: 9.24,
#  56824: 8.78,
#  50319: 9.45,
#  37500: 8.5,
#  72448: 9.29,
#  44925: 8.64,
#  12079: 8.7,
#  2506: 8.96,
#  99633: 8.75,
#  50: 9.23,
#  8477: 8.91,
#  18335: 8.51,
#  65875: 8.91,
#  43614: 8.71,
#  16603: 9.13,
#  4389: 9.24,
#  33005: 8.42,
#  52498: 7.98,
#  50412: 9.57,
#  64324: 7.74,
#  31907: 9.05,
#  75011: 8.23,
#  60769: 8.98,
#  614: 8.51,
#  64144: 8.94,
#  79579: 9.35,
#  33068: 9.15,
#  52561: 8.8,
#  72394: 8.59,
#  11188: 7.44,
#  26283: 8.78,
#  30803: 9.11,
#  85434: 8.79,
#  44885: 8.71,
#  90091: 9.0,
#  47561: 8.89,
#  57331: 8.98,
#  33539: 8.51,
#  94098: 8.75,
#  99052: 9.15,
#  ...}

# %%
total_scores
# Out:
# {22652: 14.74,
#  79330: 14.51,
#  21824: 14.7,
#  50905: 14.84,
#  85861: 14.76,
#  55337: 14.22,
#  5489: 14.03,
#  75232: 14.74,
#  81972: 14.28,
#  34296: 14.24,
#  594: 14.54,
#  46821: 14.29,
#  1789: 14.12,
#  45681: 14.22,
#  2536: 14.42,
#  51979: 14.27,
#  76213: 14.02,
#  50935: 13.99,
#  33288: 14.52,
#  60420: 13.95,
#  96594: 14.18,
#  83759: 14.64,
#  18048: 14.34,
#  28323: 14.16,
#  57228: 13.86,
#  38283: 13.64,
#  22470: 13.97,
#  89755: 14.15,
#  53437: 14.11,
#  24674: 13.5,
#  80358: 14.3,
#  86876: 14.23,
#  20132: 14.74,
#  16614: 14.28,
#  58669: 13.93,
#  89290: 14.21,
#  91691: 14.37,
#  16564: 14.54,
#  35819: 14.06,
#  50095: 13.97,
#  74722: 14.41,
#  90341: 14.12,
#  35859: 14.34,
#  96407: 14.58,
#  30239: 13.39,
#  45514: 13.46,
#  48350: 13.76,
#  69487: 13.84,
#  94171: 14.29,
#  30918: 13.64,
#  32833: 14.35,
#  22493: 14.02,
#  35411: 14.0,
#  28182: 14.35,
#  78738: 13.99,
#  15208: 14.21,
#  32539: 14.13,
#  81472: 14.29,
#  94855: 13.78,
#  42866: 13.49,
#  24487: 13.99,
#  79760: 13.55,
#  38718: 13.65,
#  22543: 14.21,
#  41586: 13.79,
#  38354: 13.48,
#  85482: 13.92,
#  78216: 13.78,
#  90809: 14.16,
#  61742: 13.82,
#  44756: 14.19,
#  54893: 13.72,
#  15199: 14.33,
#  66956: 13.9,
#  89334: 13.97,
#  50480: 14.34,
#  96067: 14.26,
#  99714: 14.2,
#  19997: 14.2,
#  33068: 13.98,
#  58345: 13.87,
#  43999: 14.1,
#  58716: 13.62,
#  16799: 13.73,
#  66312: 14.05,
#  62334: 13.88,
#  10539: 14.37,
#  73313: 13.77,
#  4623: 13.31,
#  64369: 13.73,
#  2313: 13.86,
#  5944: 13.87,
#  3497: 13.81,
#  155: 13.85,
#  76593: 13.69,
#  2445: 13.83,
#  81253: 13.57,
#  93248: 13.89,
#  72754: 13.36,
#  4187: 13.54,
#  45402: 13.82,
#  88801: 13.81,
#  14921: 13.01,
#  38688: 14.0,
#  27163: 13.94,
#  4885: 14.47,
#  59209: 13.29,
#  20101: 13.58,
#  2247: 14.34,
#  52954: 13.34,
#  64780: 13.77,
#  3269: 13.88,
#  43806: 13.71,
#  9041: 14.66,
#  97880: 13.8,
#  90342: 13.62,
#  57460: 13.82,
#  91197: 14.23,
#  80943: 13.99,
#  40644: 14.07,
#  9872: 13.02,
#  68701: 13.88,
#  91618: 13.15,
#  78315: 14.54,
#  79121: 13.92,
#  76850: 13.48,
#  93976: 13.58,
#  11283: 14.49,
#  751: 13.72,
#  35130: 13.98,
#  17823: 14.26,
#  56109: 14.27,
#  57061: 13.93,
#  15163: 14.31,
#  58750: 13.61}

# %%
k
# Out:
# 5

# %%
Wk
# Out:
# [(50905, 14.84),
#  (85861, 14.76),
#  (22652, 14.74),
#  (75232, 14.74),
#  (20132, 14.74)]

# %%
Wk
# Out:
# [(50905, 14.84),
#  (85861, 14.76),
#  (22652, 14.74),
#  (75232, 14.74),
#  (20132, 14.74)]

# %%
Wk[4][1]
# Out:
# 14.74

# %%
for obj in lower_bounds:
    print(lower_bounds[obj])
    break
# Out:
# 9.4

# %%
sequential_accesses
# Out:
# 3018
